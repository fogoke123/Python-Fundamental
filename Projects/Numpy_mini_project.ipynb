# %% [markdown]
# <a href="https://colab.research.google.com/github/fogoke123/Python-Fundamental/blob/main/Numpy_mini_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Investigate, wrangle, add new data to the dataframe, filter and correlate
#
# The following data file contains data about student scores in math, reading and writing.  The exam scores are assumed to be percentages. It also contains data about gender, ethnicity, parental education, whether the student qualifies for free school food and whether or not the student has taken a preparation course for the exams.  The data set has already been cleaned.
#
# 1.  Investigate the data set.
#
# 2.  Create numpy arrays to hold each of the three sets of scores.
# Create a new numpy array to hold the average exam score (of the three scores for each student)
# Add the new numpy array as a new column in the dataframe.
#
# 3.  Filter the original dataset into a new dataframe containing just the females.  Calculate the average exam scores for all rows in this new dataframe and then find the mean of the average column.
#
# 4.  Do the same for the males.
#
# 5.  Use the original dataset to find the correlation coefficient for reading and maths.  How closely do they correlate?  Write what you find in a text box below the code.
#
# 6.  Do the same for reading and writing. What do you find?
#
# 7.  You might want to filter on different criteria and check correlation (e.g. those on free school meals, or those who had prepared, etc)

# %% [markdown]
# The dataset can be accessed here:  https://raw.githubusercontent.com/lilaceri/Working-with-data-/main/Data%20Sets%20for%20code%20divisio/exams.csv.  This is a .csv file.
#
# **NOTE:** Some useful references are included at the bottom of this spreadsheet.
#
# Use the code cell below to work your code.

# %% [markdown]
# ###**Investigate the data set**.###
#
# The dataset was stored in a csv file and inported using the pd.read_csv, the .info() was used to inspect the dataset, checking for columns, rows, datatype, non-null and null values.

# %%
import pandas as pd
import numpy as np

url = "https://raw.githubusercontent.com/lilaceri/Working-with-data-/main/Data%20Sets%20for%20code%20divisio/exams.csv"
def data_import():

  educa_df = pd.read_csv(url)
  educa_df.info()
  print(educa_df)

data_import()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   gender              1000 non-null   object
#  1   ethnicity           1000 non-null   object
#  2   parental_education  1000 non-null   object
#  3   lunch               1000 non-null   object
#  4   preparation_course  1000 non-null   object
#  5   math_score          1000 non-null   int64
#  6   reading_score       1000 non-null   int64
#  7   writing_score       1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB
#      gender ethnicity  parental_education         lunch preparation_course  \
# 0    female   group E        some college  free/reduced               none
# 1      male   group C        some college      standard          completed
# 2    female   group B    some high school  free/reduced          completed
# 3      male   group D    some high school      standard          completed
# 4    female   group C         high school  free/reduced          completed
# ..      ...       ...                 ...           ...                ...
# 995    male   group B        some college      standard          completed
# 996    male   group D         high school      standard          completed
# 997  female   group C  associate's degree      standard          completed
# 998    male   group B     master's degree  free/reduced               none
# 999    male   group B        some college      standard               none
#
#      math_score  reading_score  writing_score
# 0            65             76             71
# 1            75             72             69
# 2            62             56             61
# 3            60             60             59
# 4            34             54             55
# ..          ...            ...            ...
# 995          80             73             74
# 996          82             87             82
# 997          65             94             93
# 998          62             62             57
# 999          38             39             40
#
# [1000 rows x 8 columns]

# %% [markdown]
# ###**Create numpy arrays**###
#
# Create numpy arrays to hold each of the three sets of scores.
# Create a new numpy array to hold the average exam score (of the three scores for each student) Add the new numpy array as a new column in the dataframe.

# %%
import pandas as pd
import numpy as np

def new_array():
#Create numpy arrays to hold each of the three sets of scores.
#Create a new numpy array to hold the average exam score (of the three scores for each student) Add the new numpy array as a new column in the dataframe.
  arr_math = educa_df['math_score'].to_numpy(np.int64)
  arr_reading = educa_df['reading_score'].to_numpy(np.int64)
  arr_writing = educa_df['writing_score'].to_numpy(np.int64)
  ave_score = arr_math*arr_reading*arr_writing/1000
  educa_df['new_ave-score'] = ave_score.tolist()
  print(educa_df)
  

new_array()
# Out:
#      gender ethnicity  parental_education         lunch preparation_course  \
# 0    female   group E        some college  free/reduced               none
# 1      male   group C        some college      standard          completed
# 2    female   group B    some high school  free/reduced          completed
# 3      male   group D    some high school      standard          completed
# 4    female   group C         high school  free/reduced          completed
# ..      ...       ...                 ...           ...                ...
# 995    male   group B        some college      standard          completed
# 996    male   group D         high school      standard          completed
# 997  female   group C  associate's degree      standard          completed
# 998    male   group B     master's degree  free/reduced               none
# 999    male   group B        some college      standard               none
#
#      math_score  reading_score  writing_score  new_ave-score
# 0            65             76             71        350.740
# 1            75             72             69        372.600
# 2            62             56             61        211.792
# 3            60             60             59        212.400
# 4            34             54             55        100.980
# ..          ...            ...            ...            ...
# 995          80             73             74        432.160
# 996          82             87             82        584.988
# 997          65             94             93        568.230
# 998          62             62             57        219.108
# 999          38             39             40         59.280
#
# [1000 rows x 9 columns]

# %% [markdown]
# If you llok at the new dataset you will see the new column created as new_ave-score which is holding average exam score
#
#
# *   arr_math
# *   arr_reading
# *   arr_writing

# %% [markdown]
# ###**Filter the original dataset for females only**###
#
# Filter the original dataset into a new dataframe containing just the females. Calculate the average exam scores for all rows in this new dataframe and then find the mean of the average column.

# %%
import pandas as pd
import numpy as np
#df = pd.read_csv("https://raw.githubusercontent.com/lilaceri/Working-with-data-/main/Data%20Sets%20for%20code%20divisio/exams.csv")

def female_score():
#Filter the original dataset into a new dataframe containing just the females. 
#Calculate the average exam scores for all rows in this new dataframe and then find the mean of the average column.
  df[df.gender == 'female']
  arr_math = df['math_score'].to_numpy(np.int64)
  arr_reading = df['reading_score'].to_numpy(np.int64)
  arr_writing = df['writing_score'].to_numpy(np.int64)
  ave_score = arr_math*arr_reading*arr_writing/496
  df['new_ave_female_score'] = ave_score.tolist()
  print(df[df.gender == 'female'])
  print(ave_score)
  

female_score()
# Out:
#      gender ethnicity  parental_education         lunch preparation_course  \
# 0    female   group E        some college  free/reduced               none
# 2    female   group B    some high school  free/reduced          completed
# 4    female   group C         high school  free/reduced          completed
# 5    female   group B        some college  free/reduced               none
# 6    female   group D        some college      standard               none
# ..      ...       ...                 ...           ...                ...
# 989  female   group D  associate's degree      standard          completed
# 991  female   group C        some college      standard               none
# 992  female   group C        some college  free/reduced               none
# 994  female   group D  associate's degree      standard          completed
# 997  female   group C  associate's degree      standard          completed
#
#      math_score  reading_score  writing_score  new_ave-score  \
# 0            65             76             71        350.740
# 2            62             56             61        211.792
# 4            34             54             55        100.980
# 5            53             66             61        213.378
# 6            85             88             92        688.160
# ..          ...            ...            ...            ...
# 989          67             81             82        445.014
# 991          68             77             77        403.172
# 992          46             62             65        185.380
# 994          72             74             80        426.240
# 997          65             94             93        568.230
#
#      new_ave_female_score
# 0              707.137097
# 2              427.000000
# 4              203.588710
# 5              430.197581
# 6             1387.419355
# ..                    ...
# 989            897.205645
# 991            812.846774
# 992            373.750000
# 994            859.354839
#   237.09677419  952.99395161  762.39516129  310.28225806  418.04435484
#   535.5         497.67741935  405.84677419  344.5        1371.77419355
#  1355.27620968  419.66129032  873.2358871   511.875       897.20564516
#   550.40322581  812.84677419  373.75        857.21370968  859.35483871
#   871.29032258 1179.41129032 1145.625       441.75        119.51612903]

# %% [markdown]
# ###**Filter the original dataset for males only**###
#
# Filter the original dataset into a new dataframe containing just the males. Calculate the average exam scores for all rows in this new dataframe and then find the mean of the average column.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/lilaceri/Working-with-data-/main/Data%20Sets%20for%20code%20divisio/exams.csv")

def male_score():
#Filter the original dataset into a new dataframe containing just the males. 
#Calculate the average exam scores for all rows in this new dataframe and then find the mean of the average column.
  df[df.gender == 'male']
  arr_math = df['math_score'].to_numpy(np.int64)
  arr_reading = df['reading_score'].to_numpy(np.int64)
  arr_writing = df['writing_score'].to_numpy(np.int64)
  ave_score = arr_math*arr_reading*arr_writing/504
  df['new_ave_male_score'] = ave_score.tolist()
  print(df[df.gender == 'male'])
  print(ave_score)
  
  

male_score()
# Out:
#     gender ethnicity  ... writing_score new_ave_male_score
# 1     male   group C  ...            69         739.285714
# 3     male   group D  ...            59         421.428571
# 7     male   group E  ...            70         942.916667
# 9     male   group C  ...            82        1037.202381
# 13    male   group C  ...            81        1171.607143
# ..     ...       ...  ...           ...                ...
# 993   male   group E  ...            69         843.607143
# 995   male   group B  ...            74         857.460317
# 996   male   group D  ...            82        1160.690476
# 998   male   group B  ...            57         434.738095
# 999   male   group B  ...            40         117.619048
#
# [504 rows x 9 columns]
# [ 695.91269841  739.28571429  420.22222222  421.42857143  200.35714286
#   423.36904762 1365.3968254   942.91666667  514.75       1037.20238095
#  1424.17460317  517.5         114.         1171.60714286  223.47619048
#   480.25396825  565.60515873  386.66666667  231.          912.57539683
#   869.           89.375       969.91071429 1091.38095238  601.25
#   373.33333333  561.26984127  159.71428571 1380.         1080.31746032
#   445.5         852.6984127   585.55555556  962.73412698  960.63492063
#  1748.21428571  756.25        365.23809524 1028.25396825  999.76190476
#  1261.5         427.11111111  427.75       1826.78571429  628.11904762
#  1027.27777778 1396.10714286  632.91071429  289.28571429  448.42261905
#   977.77777778  660.42857143 1486.76785714  441.75        614.42857143
#   551.11111111  667.42857143  688.9047619   702.84920635 1559.61904762
#   909.48412698 1055.52777778  150.41468254  500.82539683  186.12698413
#   944.44444444  440.          736.20238095 1646.82539683  380.45634921
#  1437.91666667  670.55555556  425.          866.66666667  648.38095238
#   779.02777778 1319.5        1715.87301587  128.32539683 1050.42857143
#  1028.25396825  728.84126984  378.64285714 1254.5952381   288.16666667
#  1444.82142857   21.66666667 1462.14285714  353.64880952  404.57142857
#  1866.07142857  268.25396825  175.71428571  778.76190476  746.42857143
#   352.80753968  546.92063492 1133.33333333 1282.5         740.42857143
#   372.53571429 1555.71428571 1046.4781746   812.77777778 1305.86309524
#   297.66666667  943.13690476  480.53571429  987.10714286  587.17460317
#   411.42857143  242.28571429  411.75        716.52777778  708.48214286
#   527.42857143  659.60714286  511.875       480.5         303.80952381
#   318.21428571  200.44444444  595.55555556  511.5         475.35714286
#   344.5         402.79365079  643.0952381   561.26984127  225.23809524
#   228.          446.25        570.29761905  351.         1152.23214286
#   821.97619048  578.28571429  384.01785714  578.78571429 1024.55357143
#   559.28571429 1077.38888889  536.25        369.14285714  417.21428571
#   518.98412698  240.66666667 1539.41666667  399.88888889  203.29166667
#   776.28571429 1068.70634921  335.5        1144.46428571  983.06547619
#   429.          902.65079365  989.08333333  968.33333333 1305.33333333
#   352.68650794  366.12103175  809.51785714 1576.92460317 1082.25
#   300.53571429  679.5952381    95.82936508 1490.0297619   414.4047619
#   518.5         415.28571429  230.61309524  748.          346.27380952
#   649.61309524  385.          950.          600.875       529.96428571
#  1045.17460317  368.75       1052.54960317  552.21825397  256.66666667
#   344.16666667 1063.3968254   959.65079365 1035.8531746   842.78571429
#  1041.26984127 1014.77380952 1039.80555556 1828.37301587  387.5
#   407.15079365  677.97619048  646.875       657.14285714 1161.66666667
#   487.92857143  879.04761905 1259.28571429 1570.47619048  175.
#   666.66666667  665.625       290.95238095  899.          771.2797619
#   233.33333333  937.86706349  750.29365079  305.35714286  411.40873016
#   527.          489.77777778  399.4047619   339.03174603 1350.
#  1333.76388889  413.          859.375       503.75        882.96428571
#   541.66666667  799.94444444  367.81746032  843.60714286  845.71428571
#   857.46031746 1160.69047619 1127.44047619  434.73809524  117.61904762]

# %% [markdown]
# ###**Find the correlation coefficient for reading and maths.**###
#
# Use the original dataset to find the correlation coefficient for reading and maths. How closely do they correlate? Write what you find in a text box below the code.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/lilaceri/Working-with-data-/main/Data%20Sets%20for%20code%20divisio/exams.csv")

def coe_reading_math():

#Use the original dataset to find the correlation coefficient for reading and maths. How closely do they correlate? Write what you find in a text box below the code.
   array_reading = arr = df['reading_score'].to_numpy(np.int32)
   array_math = arr = df['math_score'].to_numpy(np.int32)
   array_coef = np.corrcoef(array_reading,array_math)
   print(array_coef)

coe_reading_math()
# Out:
# [[1.         0.81459752]
#  [0.81459752 1.        ]]

# %% [markdown]
# ###**Find the correlation coefficient for reading and writing.**###

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/lilaceri/Working-with-data-/main/Data%20Sets%20for%20code%20divisio/exams.csv")

def coe_reading_writing():

#Use the original dataset to find the correlation coefficient for reading and writing. How closely do they correlate? Write what you find in a text box below the code.
   array_reading = arr = df['reading_score'].to_numpy(np.int32)
   array_writing = arr = df['writing_score'].to_numpy(np.int32)
   array_coef = np.corrcoef(array_reading,array_writing)
   print(array_coef)

coe_reading_writing()
# Out:
# [[1.         0.95676863]
#  [0.95676863 1.        ]]

# %% [markdown]
# You might want to filter on different criteria and check correlation (e.g. those on free school meals, or those who had prepared, etc)

# %% [markdown]
# ###**Reflection**###

# %% [markdown]
# ###**What skills have you demonstrated in completing this notebook?**###
#
# How to Investigate, wrangle, add new data to the dataframefilter and correlate  to help find or calculate projections.

# %% [markdown]
# ### Helpful references
# ---
#
# Filtering on criteria using df references:
# `filtered_df = df[df['column name' == value]]`
#
# Filtering on multiple criteria using df reference:
# `filtered_df = df[df['first column name' == value] & df[second column name] >= value]`
#
# Numpy help sheet:  http://datacamp-community-prod.s3.amazonaws.com/da466534-51fe-4c6d-b0cb-154f4782eb54
